# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %%
data1 = pd.read_csv("NewspaperData.csv")
data1
# Out:
#                          Newspaper     daily    sunday
# 0                    Baltimore Sun   391.952   488.506
# 1                     Boston Globe   516.981   798.298
# 2                    Boston Herald   355.628   235.084
# 3               Charlotte Observer   238.555   299.451
# 4                Chicago Sun Times   537.780   559.093
# 5                  Chicago Tribune   733.775  1133.249
# 6              Cincinnati Enquirer   198.832   348.744
# 7                      Denver Post   252.624   417.779
# 8              Des Moines Register   206.204   344.522
# 9                 Hartford Courant   231.177   323.084
# 10               Houston Chronicle   449.755   620.752
# 11                Kansas City Star   288.571   423.305
# 12         Los Angeles Daily  News   185.736   202.614
# 13               Los Angeles Times  1164.388  1531.527
# 14                    Miami Herald   444.581   553.479
# 15        Minneapolis Star Tribune   412.871   685.975
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Newspaper  34 non-null     object
#  1   daily      34 non-null     float64
#  2   sunday     34 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 948.0+ bytes

# %%
data1.describe()
# Out:
#              daily       sunday
# count    34.000000    34.000000
# mean    430.962471   591.202412
# std     269.211470   376.418051
# min     133.239000   202.614000
# 25%     233.021500   327.769500
# 50%     355.235500   436.712500
# 75%     516.616500   699.735250
# max    1209.225000  1762.015000

# %%
#Boxplot for daily column
plt.figure(figsize=(6,3))
plt.title("Box plot for Daily Sales")
plt.boxplot(data1["daily"], vert=False)
plt.show()

# %%
sns.histplot(data1['daily'], kde=True, stat='density',)
plt.show()

# %% [markdown]
# Scatter plot and Correlation Strength

# %%
x=data1['daily']
y=data1['sunday']
plt.scatter(data1['daily'], data1['sunday'])
plt.xlim(0, max(x)+100)
plt.ylim(0, max(y)+100)
plt.show()

# %%
data1['daily'].corr(data1['sunday'])
# Out:
# 0.9581543140785462

# %%
data1[['daily','sunday']].corr()
# Out:
#            daily    sunday
# daily   1.000000  0.958154
# sunday  0.958154  1.000000

# %% [markdown]
# Observations:
# The relationship between x(daily) and y(sunday) is seen to be linear as seen from scatter plot.
# The correlation is strong positive with Pearson's correlation coefficient of 0.958154

# %% [markdown]
# Prediction equation for linear regression is y=(beta)o=(beta1)x
# Modal equation for linear regression is y=(beta)o=(beta1)x+error

# %%
model1 = smf.ols("sunday~daily", data = data1).fit()

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 sunday   R-squared:                       0.918
# Model:                            OLS   Adj. R-squared:                  0.915
# Method:                 Least Squares   F-statistic:                     358.5
# Date:                Tue, 04 Feb 2025   Prob (F-statistic):           6.02e-19
# Time:                        12:00:07   Log-Likelihood:                -206.85
# No. Observations:                  34   AIC:                             417.7
# Df Residuals:                      32   BIC:                             420.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     13.8356     35.804      0.386      0.702     -59.095      86.766
# ...

# %%
#Plot the scatter plot and overlay the fited straight line using matplotlib
x=data1['daily'].values
y=data1['sunday'].values
plt.scatter(x, y, color='m', marker='o', s=30)
b0=13.84
b1=1.33

#predicted response vector
y_hat=b0+b1*x

#plotting the regression line
plt.plot(x, y, color='g')

#putting labels
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
#plot the linear regression line using seaborn regplot() method
sns.regplot(x='daily', y='sunday', data=data1)
plt.xlim([0,1250])
plt.show()

# %% [markdown]
# Predict for new data points(test data)

# %%
newdata=pd.Series([200,300,1500])

# %%
data_pred=pd.DataFrame(newdata,columns=['daily'])
data_pred
# Out:
#    daily
# 0    200
# 1    300
# 2   1500

# %%
model1.predict(data_pred)
# Out:
# 0     281.778581
# 1     415.750057
# 2    2023.407766
# dtype: float64

# %%
pred=model1.predict(data1['daily'])
pred
# Out:
# 0      538.939509
# 1      706.442705
# 2      490.275710
# 3      333.431284
# 4      734.307432
# 5      996.884826
# 6      280.213795
# 7      352.279731
# 8      290.090172
# 9      323.546868
# 10     616.379041
# 11     400.438457
# 12     262.668890
# 13    1573.783417
# 14     609.447357
# 15     566.965002
# 16     378.613164
# 17    1061.219269
# 18    1633.852208
# 19    1119.786239
# 20     313.594128
# 21     489.224034
# 22     704.489401
# 23     309.195844
# 24     466.219792
# 25     277.920203
# 26     192.337885
# 27     514.901007
# 28     380.708478
# 29     777.960698
# 30     538.047259
# 31     284.270451
# 32     444.722729
# 33    1137.725020
# dtype: float64

# %%
data1["Y_hat"] = pred
data1
# Out:
#                          Newspaper     daily    sunday        Y_hat
# 0                    Baltimore Sun   391.952   488.506   538.939509
# 1                     Boston Globe   516.981   798.298   706.442705
# 2                    Boston Herald   355.628   235.084   490.275710
# 3               Charlotte Observer   238.555   299.451   333.431284
# 4                Chicago Sun Times   537.780   559.093   734.307432
# 5                  Chicago Tribune   733.775  1133.249   996.884826
# 6              Cincinnati Enquirer   198.832   348.744   280.213795
# 7                      Denver Post   252.624   417.779   352.279731
# 8              Des Moines Register   206.204   344.522   290.090172
# 9                 Hartford Courant   231.177   323.084   323.546868
# 10               Houston Chronicle   449.755   620.752   616.379041
# 11                Kansas City Star   288.571   423.305   400.438457
# 12         Los Angeles Daily  News   185.736   202.614   262.668890
# ...

# %%
data1["residuals"] =data1["sunday"]-data1["Y_hat"]
data1
# Out:
#                          Newspaper     daily    sunday        Y_hat  \
# 0                    Baltimore Sun   391.952   488.506   538.939509
# 1                     Boston Globe   516.981   798.298   706.442705
# 2                    Boston Herald   355.628   235.084   490.275710
# 3               Charlotte Observer   238.555   299.451   333.431284
# 4                Chicago Sun Times   537.780   559.093   734.307432
# 5                  Chicago Tribune   733.775  1133.249   996.884826
# 6              Cincinnati Enquirer   198.832   348.744   280.213795
# 7                      Denver Post   252.624   417.779   352.279731
# 8              Des Moines Register   206.204   344.522   290.090172
# 9                 Hartford Courant   231.177   323.084   323.546868
# 10               Houston Chronicle   449.755   620.752   616.379041
# 11                Kansas City Star   288.571   423.305   400.438457
# 12         Los Angeles Daily  News   185.736   202.614   262.668890
# ...

# %%
mse = np.mean((data1["daily"]-data1["Y_hat"])**2)
rmse = np.sqrt(mse)
print("MSE: ",mse)
print("RMSE: ",rmse)
# Out:
# MSE:  33794.87469205266
# RMSE:  183.83382358002746

# %%
mae = np.mean(np.abs(data1["daily"]-data1["Y_hat"]))
mae
# Out:
# 160.23994117647064

# %%
#plot the residuals versus y_hat
plt.scatter(data1["Y_hat"],data1["residuals"])
plt.xlabel('Y_hat')
plt.ylabel('Residuals')
# Out:
# Text(0, 0.5, 'Residuals')

# %% [markdown]
# Observations:
# There appears to be no trend and the residuals are randomly placed around the zero error line. Hence the assumption of homoscedasticty is satisfies

# %%
#Plot the Q-Q plot (to check the normality of residuals)
import statsmodels.api as sm
sm.qqplot(data1["residuals"], line='45', fit=True)
plt.show()

# %%
sns.histplot(data1['residuals'], kde=True)
# Out:
# <Axes: xlabel='residuals', ylabel='Count'>

# %% [markdown]
# Observations: The data points are seen closely follow the reference line of normality. Hence the residuals are approximately normally distributed as also can be seen from the kde distribution. All the assumptions of simple linear regression are verified and found to be valid in this case.
